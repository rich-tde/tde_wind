# %%
import Utilities.prelude
import numpy as np

# %%
snap = 100
path = f'data/{snap}/'

# %%
# Load data
sedov = np.loadtxt(f'{path}shockzone_{snap}.txt')
xshock = sedov[0]
yshock = sedov[1]
zshock = sedov[2]
