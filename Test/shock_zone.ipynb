# %% [markdown]
# Implement and test the 3 conditions of Schaal14 for shock detection

# %%
import Utilities.prelude
import pickle 
import numpy as np
import matplotlib.pyplot as plt
import math
import k3match
from Utilities.operators import make_tree, calc_grad, calc_div

# %%
gamma = 5/3
mach_min = 1.3
save = False
folder = 'TDE'
snap = '683'
path = f'{folder}/{snap}'

if folder == 'TDE':
    is_tde = True
    threshold = 7_000
else:
    is_tde = False
    threshold = 0.99

# %%
def temperature_bump(mach, gamma):
    """ T_post/ T_pre shock according to RH conditions."""
    Tbump =  (mach**2 * (gamma-1) + 2) * (2 * gamma * mach**2 - (gamma-1)) / (mach**2 * (gamma+1)**2)
    return Tbump

def pressure_bump(mach, gamma):
    """ P_post/ P_pre shock according to RH conditions."""
    Pbump = (2 * gamma * mach**2 - (gamma-1)) / (gamma+1)
    return Pbump

def shock_direction(sim_tree, X, Y, Z, Temp, point, delta):
    """ Find shock direction according eq.(5) by Schaal14 in the point of coordinates indices idx.
    Parameters
    -----------
    sim_tree: tree.
            Simulation points.
    X, Y, Z, Temp: arrays.
            Coordinates and temperature of the points of the tree.
    point: array.
            Starting point.
    delta: float.
            Step between 2 neighbours.
    Returns
    -----------
    grad: array.
        Gradient of temperature(vector of 3 components).
    ds: array.
        Shock direction (vector of 3 components).
    """
    grad = calc_grad(sim_tree, X, Y, Z, Temp, point, delta)
    magnitude = np.linalg.norm(grad)
    
    if np.linalg.norm(grad) <1e-3:#np.logical_and(np.abs(grad[0])<1, np.logical_and(np.abs(grad[1])<1, np.abs(grad[2])<1)):
        ds = np.zeros(3)
    else:
        ds = - np.divide(grad,magnitude)

    return grad, ds
 
def find_prepost(sim_tree, X, Y, Z, point, ds, delta, direction):
    """
    Parameters
    -----------
    point: array.
        Starting point.
    ds: array (1x3)
        Shock direction.
    delta: float.
        Step to do to search.
    direction: str.
        Choose pre or post shock.
    Returns
    -----------
    idx: int.
        Index of the pre/post shock point
    """
    if direction == 'post':
        delta = - delta

    k = 1
    # check that you are not taking the same point as the one given
    distance = 0
    while distance == 0:
        new_point = point + k * delta * ds 
        _, idx  = sim_tree.query(new_point)
        check_point = np.array([X[idx], Y[idx], Z[idx]])
        distance = math.dist(point, check_point)
        k += 0.1

    return idx

def condition3(sim_tree, X, Y, Z, Press, Temp, point, ds, mach_min, gamma, delta):
    """ Last condition fot shock zone by Schaal14 .
    Parameters
    -----------
    sim_tree: tree.
            Simulation points.
    X, Y, Z, Press, Temp: arrays.
            Coordinates, pressure and temperature of the points of the tree.
    point: array.
            Starting point.
    ds: array (1x3)
        Shock direction.
    mach_min, gamma: floats.
                    Minimum mach number, adiabatic index.
    delta: float.
            Step between 2 neighbours.
    Returns
    -----------
    bool.
        If condition is satisfied or not.
    """
    # Find (the index in the tree of) the point in the pre/post shock region.
    idxpost = find_prepost(sim_tree, X, Y, Z, point, ds, delta, direction = 'post') 
    idxpre = find_prepost(sim_tree, X, Y, Z, point, ds, delta, direction = 'pre') 

    # Store data from the tree
    Tpost = Temp[idxpost]
    Ppost = Press[idxpost]
    Tpre = Temp[idxpre]
    Ppre = Press[idxpre]

    # Last condition fot shock zone by Schaal14
    delta_logT = np.log(Tpost) - np.log(Tpre)
    Tjump = temperature_bump(mach_min, gamma)
    Tjump = np.log(Tjump)
    ratioT = delta_logT / Tjump 
    delta_logP = np.log(Ppost)-np.log(Ppre)
    Pjump = pressure_bump(mach_min, gamma)
    Pjump = np.log(Pjump)
    ratioP = delta_logP / Pjump 
    
    if np.logical_and(ratioT >= 1, ratioP >= 1): 
        return True
    else:
        return False
    
def shock_zone(divv, gradT, gradrho, cond3, check_cond = '3'):
    """ Find the shock zone according conditions in Sec. 2.3.2 of Schaal14. 
    In order to test the code, with "check_con" you can decide if checking all or some of the conditions."""
    if check_cond == '1' or check_cond == '2':
        cond3 = True # so you don't check it
        if check_cond == '2':
            cond2 = np.dot(gradT, gradrho)
        else:
            cond2 = 10
    else:
        cond2 = np.dot(gradT, gradrho)

    if np.logical_and(divv<0, np.logical_and(cond2 > 0, cond3 == True)):
        return True
    else:
        return False

# %%
sim_tree, X, Y, Z, Vol, VX, VY, VZ, Den, Press, Temp = make_tree(path, snap, is_tde)
dim_cell = (3*Vol/(4*np.pi))**(1/3)

# %%
# Floor density
# idx = np.argmax(Den)
# xmax = X[idx]
# ymax = Y[idx]
# print(f'The density floor is {np.min(Den)}')
# mindenstream = np.min(Den[np.logical_and(np.abs(ymax-Y)<11,np.abs(xmax-X)<11)])
# print(f'The minimum around the stream is {mindenstream}')

# %%
shock_dirx = []
shock_diry = []
shock_dirz = []
X_shock1 = []
Y_shock1 = []
Z_shock1 = []
X_shock2 = []
Y_shock2 = []
Z_shock2 = []
X_shock = []
Y_shock = []
Z_shock = []
div_shock = []
T_shock = []
are_u_shock = np.zeros(len(X), dtype = bool)
x_who = []
y_who = []
z_who = []
idx_tree = []

masked = 0
for i in range(len(X)):
    # print(i)
    point = np.array([X[i],Y[i],Z[i]])

    if np.linalg.norm(point)>threshold:
        masked += 1
        are_u_shock[i] = False
        continue

    step = 2*dim_cell[i]
    grad_temp, ds = shock_direction(sim_tree, X, Y, Z, Temp, point, step)
    
    # fondamentale!!
    if np.linalg.norm(ds) == 0 or Den[i]<1e-15:
        are_u_shock[i] = False
        continue
    
    div_vel = calc_div(sim_tree, X, Y, Z, VX, VY, VZ, point, step)
    grad_den = calc_grad(sim_tree, X, Y, Z, Den, point, step)

    if math.isnan(np.linalg.norm(grad_temp)):
        # non dovrebbe succedere se prendi ds=2*max
        are_u_shock[i] = False
        print(f'nan in grad temp of cell {i}, change step')
        x_who.append(X[i])
        y_who.append(Y[i])
        z_who.append(Z[i])
        continue 

    if math.isnan(np.linalg.norm(div_vel)):
        # non dovrebbe succedere per come prendi step in ds=2*max
        are_u_shock[i] = False
        print('nan in div_v')

    cond3 = condition3(sim_tree, X, Y, Z, Press, Temp, point, ds, mach_min, gamma, step)
    shock1 = shock_zone(div_vel, grad_temp, grad_den, cond3, check_cond =  '1')
    shock2 = shock_zone(div_vel, grad_temp, grad_den, cond3, check_cond =  '2')
    shock = shock_zone(div_vel, grad_temp, grad_den, cond3, check_cond = '3')
    are_u_shock[i] = shock
    
    if shock1 == True:
        X_shock1.append(X[i])
        Y_shock1.append(Y[i])
        Z_shock1.append(Z[i])

    if shock2 == True:
        X_shock2.append(X[i])
        Y_shock2.append(Y[i])
        Z_shock2.append(Z[i])

    if shock == True:
        X_shock.append(X[i])
        Y_shock.append(Y[i])
        Z_shock.append(Z[i])
        shock_dirx.append(ds[0])
        shock_diry.append(ds[1])
        shock_dirz.append(ds[2])
        div_shock.append(div_vel)
        T_shock.append(Temp[i])
        idx_tree.append(i)

print(masked)
# Out:
# lots of iterations for div/grad in y for point [-3409.66861446  5775.63035953 -1587.29365423]. Skip
# lots of iterations for div/grad in y for point [-2135.11253816  5772.28533761 -1720.13307596]. Skip
# lots of iterations for div/grad in z for point [-2173.57760523  1302.71408569  5954.66892639]. Skip
# lots of iterations for div/grad in y for point [-2649.58600767  5786.14040012   284.9768184 ]. Skip
# lots of iterations for div/grad in y for point [-2933.99684388  5750.52204721  1640.2023556 ]. Skip
# lots of iterations for div/grad in z for point [-2779.98123589  1030.83176332  5954.0933792 ]. Skip
# lots of iterations for div/grad in z for point [-2791.32931571  -199.54552113  5939.92946799]. Skip
# lots of iterations for div/grad in y for point [-881.70255336 5764.12249307  -16.29489801]. Skip
# lots of iterations for div/grad in z for point [-1044.72347664  2166.33185433  5959.47056042]. Skip
# lots of iterations for div/grad in z for point [-1199.27653625 -1257.87776486  5958.51321716]. Skip
# lots of iterations for div/grad in z for point [-1229.74173007 -2381.42739834  5944.59576519]. Skip
# lots of iterations for div/grad in y for point [-1319.63628258  5774.24951138  2631.30224658]. Skip
# lots of iterations for div/grad in y for point [-1383.71376508  5765.70713734  -905.33166356]. Skip
# lots of iterations for div/grad in y for point [-1731.27900614  5772.03768741  1551.76822257]. Skip
# lots of iterations for div/grad in z for point [-1826.87183823  2915.48150516  5940.29258922]. Skip
# lots of iterations for div/grad in z for point [-1965.30393223  1766.08833648  5950.62412435]. Skip
# lots of iterations for div/grad in y for point [-1943.68919036  5778.69394626 -3125.57980691]. Skip
# lots of iterations for div/grad in y for point [-1763.0750934   5775.8853104  -3476.33526607]. Skip
# lots of iterations for div/grad in y for point [-1500.54424435  5774.4219246  -2437.32442369]. Skip
# lots of iterations for div/grad in z for point [ -237.77834614 -1770.84826173  5956.43162581]. Skip
# lots of iterations for div/grad in z for point [-302.21664351 3087.6693763  5947.28320061]. Skip
# lots of iterations for div/grad in y for point [-727.60869298 5752.30567771  756.07999062]. Skip
# lots of iterations for div/grad in y for point [ 1466.24542324  5778.06122596 -1710.31935961]. Skip
# lots of iterations for div/grad in z for point [1280.94897432 -681.48911254 5967.67213898]. Skip
# lots of iterations for div/grad in z for point [  779.93796322 -1917.86956443  5957.82599959]. Skip
# lots of iterations for div/grad in y for point [ 881.83153574 5769.49718979 2712.85892245]. Skip
# lots of iterations for div/grad in y for point [ 880.66324295 5754.6883742  -401.00806567]. Skip
# lots of iterations for div/grad in y for point [ 1108.67153995  5785.0917383  -2688.70802725]. Skip
# lots of iterations for div/grad in y for point [2925.21473539 5778.26286095 1951.04057677]. Skip
# lots of iterations for div/grad in y for point [1920.47516498 5790.62315516 2169.60830673]. Skip
# lots of iterations for div/grad in x for point [ 4853.88647891 -2949.62436746 -1174.13373528]. Skip
# lots of iterations for div/grad in x for point [ 4842.61316358  4327.97588101 -1145.4988178 ]. Skip
# lots of iterations for div/grad in z for point [2890.87338114  239.59362498 5974.85040433]. Skip
# lots of iterations for div/grad in z for point [3502.94550861   71.98171404 5983.75402243]. Skip
# lots of iterations for div/grad in x for point [4838.04421371  445.9432248  3906.54470058]. Skip
# lots of iterations for div/grad in x for point [4835.74274741 2849.08211888 1778.17393357]. Skip
# lots of iterations for div/grad in z for point [1871.72259384  936.55411191 5972.93547209]. Skip
# lots of iterations for div/grad in x for point [ 4844.65309441  3448.62535822 -3488.3543602 ]. Skip
# lots of iterations for div/grad in x for point [ 4827.65121982 -2799.42254124  1078.79298216]. Skip
# lots of iterations for div/grad in x for point [4833.28844341 1685.91857931  587.88460038]. Skip
# lots of iterations for div/grad in x for point [ 4844.07068016 -1813.87815153 -4172.72691007]. Skip
# lots of iterations for div/grad in x for point [4828.23599879 2196.11736771 4190.47303665]. Skip
# lots of iterations for div/grad in y for point [3605.83509161 5778.03939404 -562.60930822]. Skip
# lots of iterations for div/grad in x for point [ 4837.46711173  1585.84076328 -2445.61334281]. Skip
# lots of iterations for div/grad in x for point [4839.30021199  640.33717916 3569.12024361]. Skip
# lots of iterations for div/grad in x for point [4828.33990078 2414.39365996 3914.38509127]. Skip
# lots of iterations for div/grad in y for point [ 2484.84550598  5784.33400555 -1474.04493815]. Skip
# lots of iterations for div/grad in y for point [3172.86462519 5783.82020471  676.20948679]. Skip
# lots of iterations for div/grad in x for point [4847.07785527  863.87282899 4407.37755944]. Skip
# lots of iterations for div/grad in y for point [ 2787.81924223  5782.80164799 -1514.49729091]. Skip
# lots of iterations for div/grad in x for point [ 4824.61307248 -1900.84270526  4178.49145886]. Skip
# lots of iterations for div/grad in y for point [3390.81489026 5775.27493698 -935.82468577]. Skip
# lots of iterations for div/grad in x for point [ 4830.50272277 -4580.18177906 -2007.30941233]. Skip
# lots of iterations for div/grad in x for point [ 4835.14611509  1859.50468585 -1279.35839913]. Skip
# lots of iterations for div/grad in x for point [4847.49343903 -713.68480138 1659.26260125]. Skip
# lots of iterations for div/grad in y for point [3100.54647824 5784.35112529  545.82859353]. Skip
# lots of iterations for div/grad in x for point [ 4827.98561103  2320.92084874 -2445.07078945]. Skip
# lots of iterations for div/grad in x for point [ 4837.54048576  1061.16200139 -2840.11240464]. Skip
# lots of iterations for div/grad in x for point [4827.20998871 2736.19061636 2900.58307822]. Skip
# lots of iterations for div/grad in x for point [ 4844.12817368 -3411.27864403 -2621.91418991]. Skip
# lots of iterations for div/grad in y for point [2585.72110596 5788.03759558  738.41529582]. Skip
# lots of iterations for div/grad in x for point [ 4819.88014619 -4401.32377651  -964.90248884]. Skip
# lots of iterations for div/grad in x for point [ 4845.91385215  -221.73873272 -1733.2720634 ]. Skip
# lots of iterations for div/grad in x for point [ 4832.37672101  1424.13315349 -3490.83324498]. Skip
# lots of iterations for div/grad in x for point [4831.93874833 1834.69294971 -741.38514197]. Skip
# lots of iterations for div/grad in z for point [3517.71346122 -783.45340305 5973.60421401]. Skip
# lots of iterations for div/grad in x for point [4840.78753575 2609.41222239  962.68840937]. Skip
# lots of iterations for div/grad in y for point [ 2495.42364056  5776.89427886 -2392.61511132]. Skip
# lots of iterations for div/grad in x for point [4826.38496428 -616.48397417 -388.61110782]. Skip
# lots of iterations for div/grad in y for point [3858.20269901 5777.82726965  498.45295015]. Skip
# lots of iterations for div/grad in x for point [4835.87542288   20.23542231 4428.01959408]. Skip
# lots of iterations for div/grad in z for point [ 2338.57032989 -2769.88838517  5974.60464959]. Skip
# lots of iterations for div/grad in z for point [2203.51941506  232.19382863 5968.51443355]. Skip
# lots of iterations for div/grad in x for point [4836.54134605 4039.34544303 2401.69253076]. Skip
# lots of iterations for div/grad in x for point [ 4850.50096089   169.01009454 -2141.3748118 ]. Skip
# lots of iterations for div/grad in x for point [4845.69652343 2533.0956886   184.96618763]. Skip
# lots of iterations for div/grad in z for point [1837.21670761 3002.31153794 5964.05027717]. Skip
# lots of iterations for div/grad in x for point [4834.11145044 -770.73612378 3050.90476653]. Skip
# lots of iterations for div/grad in x for point [ 4831.22004844  4438.60524828 -2037.81032782]. Skip
# lots of iterations for div/grad in x for point [ 4813.89073268 -4823.79304769    -9.59382964]. Skip
# lots of iterations for div/grad in x for point [ 4851.35290224 -2103.52973761 -2089.0193335 ]. Skip
# lots of iterations for div/grad in x for point [ 4837.62130521   933.72161952 -3102.93287568]. Skip
# lots of iterations for div/grad in x for point [ 4845.78091999 -2384.04655715 -1244.81277796]. Skip
# lots of iterations for div/grad in x for point [4818.66273932 4065.71724694  256.03096282]. Skip
# lots of iterations for div/grad in y for point [2752.82054352 5774.95764519 -149.17739261]. Skip
# lots of iterations for div/grad in x for point [4854.36023209   39.10218896  498.44177001]. Skip
# lots of iterations for div/grad in x for point [ 4836.4996192  -848.9590225 -2641.8901663]. Skip
# lots of iterations for div/grad in y for point [3416.6387756  5777.15065629 -261.29880595]. Skip
# lots of iterations for div/grad in z for point [2709.1607666  1989.90499631 5965.64071131]. Skip
# lots of iterations for div/grad in x for point [4831.73931709 3690.39730766 1792.69552978]. Skip
# lots of iterations for div/grad in x for point [ 4837.86782094 -3772.30357683  3178.0205063 ]. Skip
# lots of iterations for div/grad in x for point [ 4827.10801207  3041.90352028 -1477.36096718]. Skip
# lots of iterations for div/grad in x for point [4836.74380747 -805.64692271 3928.87796604]. Skip
# lots of iterations for div/grad in x for point [4829.72548704  819.43869219 2792.15829231]. Skip
# lots of iterations for div/grad in x for point [4835.04322351 4097.31949182 2634.59532434]. Skip
# lots of iterations for div/grad in x for point [ 4848.88360741 -1817.91411306   136.38633173]. Skip
# lots of iterations for div/grad in x for point [ 4836.72306259 -2814.34065255  2903.97376063]. Skip
# lots of iterations for div/grad in x for point [ 4835.2597      -450.94783465 -4327.1964753 ]. Skip
# lots of iterations for div/grad in x for point [ 4827.23617063 -1944.26619838  1852.45337796]. Skip
# lots of iterations for div/grad in x for point [ 4851.43898325 -4457.3054563   1507.87599347]. Skip
# lots of iterations for div/grad in y for point [ 2016.25042374  5771.22141535 -3117.3306496 ]. Skip
# lots of iterations for div/grad in z for point [ 2889.07004524 -2057.19042341  5974.09075363]. Skip
# lots of iterations for div/grad in x for point [ 4827.32304707 -2003.86363808  1603.59591771]. Skip
# lots of iterations for div/grad in x for point [ 4835.04778642 -4042.50760462 -2842.54939384]. Skip
# lots of iterations for div/grad in x for point [4841.26483858 3096.9916965  -722.45267899]. Skip
# lots of iterations for div/grad in x for point [ 4838.75839553 -2916.29454143  4124.10083099]. Skip
# lots of iterations for div/grad in x for point [ 4847.63971429  1433.99964251 -4461.57835688]. Skip
# lots of iterations for div/grad in x for point [ 4839.63051822 -1397.37607274  -804.8557708 ]. Skip
# lots of iterations for div/grad in z for point [2083.57502739 1685.24873832 5973.54120586]. Skip
# lots of iterations for div/grad in x for point [ 4834.50514007 -3165.34376783 -3381.73171648]. Skip
# lots of iterations for div/grad in x for point [4848.83606436 -363.73575376 1769.52120366]. Skip
# lots of iterations for div/grad in x for point [ 4844.00507039 -2091.97965101  3177.09904048]. Skip
# lots of iterations for div/grad in x for point [ 4833.66756783 -1423.88391252  4770.19046601]. Skip
# lots of iterations for div/grad in x for point [4840.87167308 1256.135063   -522.47193607]. Skip
# lots of iterations for div/grad in z for point [2119.35554267 -736.8732159  5971.64461284]. Skip
# lots of iterations for div/grad in x for point [ 4831.64386716  3145.89362531 -1904.58207355]. Skip
# lots of iterations for div/grad in x for point [4834.72093799 2663.27274226 2252.05782927]. Skip
# lots of iterations for div/grad in x for point [ 4838.2466813  -3570.07463487   263.44923957]. Skip
# lots of iterations for div/grad in y for point [ 2387.79481174  5783.70093803 -1640.91073458]. Skip
# lots of iterations for div/grad in x for point [4833.33924466 1380.61753395 1089.4810494 ]. Skip
# lots of iterations for div/grad in y for point [1953.13408755 5782.88395255  434.00023213]. Skip
# lots of iterations for div/grad in x for point [4826.77671467   50.85142121 2552.2041417 ]. Skip
# lots of iterations for div/grad in x for point [4831.68989483 1729.71517729 4467.40298328]. Skip
# lots of iterations for div/grad in x for point [4833.97065827 -518.06852898 3052.25712552]. Skip
# lots of iterations for div/grad in y for point [1975.3829503  5776.28702973 -903.99631768]. Skip
# lots of iterations for div/grad in x for point [ 4835.94089229  3006.95973479 -2704.06336063]. Skip
# lots of iterations for div/grad in x for point [ 4843.64627495 -1656.86022539 -3409.62467474]. Skip
# lots of iterations for div/grad in x for point [4838.55598154 2081.55292812 2271.46406596]. Skip
# lots of iterations for div/grad in z for point [  516.42234116 -3609.32122553  5956.34124906]. Skip
# lots of iterations for div/grad in y for point [  371.56539205  5762.15505318 -3442.5219456 ]. Skip
# lots of iterations for div/grad in z for point [  298.70455019 -2182.94844303  5956.98567035]. Skip
# lots of iterations for div/grad in z for point [ 307.60357158 3435.67752899 5952.10657431]. Skip
# lots of iterations for div/grad in y for point [ 390.43761279 5776.4044406  1712.85429544]. Skip
# lots of iterations for div/grad in y for point [ 225.71913522 5753.63418277  153.5123018 ]. Skip
# lots of iterations for div/grad in z for point [ 226.55832801 -468.30949745 5965.60219293]. Skip
# lots of iterations for div/grad in z for point [  24.00821983 1015.48751642 5944.50239527]. Skip
# lots of iterations for div/grad in z for point [ 103.5726459  1971.47369277 5939.4831463 ]. Skip
# lots of iterations for div/grad in y for point [ -57.07839059 5753.96672831 3107.75171455]. Skip
# lots of iterations for div/grad in y for point [  -6.51604962 5760.75889577 -980.79661227]. Skip
# lots of iterations for div/grad in y for point [   22.48989536  5760.00191559 -3569.76176047]. Skip
# lots of iterations for div/grad in y for point [   81.98191933  5755.55000514 -1573.04964508]. Skip
# 18488624

# %%
X_shock = np.array(X_shock)
Y_shock = np.array(Y_shock)
Z_shock = np.array(Z_shock)

X_shock1 = np.array(X_shock1)
Y_shock1 = np.array(Y_shock1)
Z_shock1 = np.array(Z_shock1)

X_shock2 = np.array(X_shock2)
Y_shock2 = np.array(Y_shock2)
Z_shock2 = np.array(Z_shock2)

# %%
if save == True:
    with open(f'data/{snap}/shockzone_{snap}.txt', 'w') as file:
        file.write(f'# Coordinates of the points in the shock zone, mach_min = {mach_min} \n# X \n') 
        file.write(' '.join(map(str, X_shock)) + '\n')
        file.write('# Y \n') 
        file.write(' '.join(map(str, Y_shock)) + '\n')
        file.write('# Z \n') 
        file.write(' '.join(map(str, Z_shock)) + '\n')
        file.write('# div v \n') 
        file.write(' '.join(map(str, div_shock)) + '\n')
        file.write('# T \n') 
        file.write(' '.join(map(str, T_shock)) + '\n')
        file.write('# index in the tree \n') 
        file.write(' '.join(map(str, idx_tree)) + '\n')
        file.close()
    with open(f'data/{snap}/shockdir_{snap}.txt', 'w') as fileds:
        fileds.write('# shock x direction \n') 
        fileds.write(' '.join(map(str, shock_dirx)) + '\n')
        fileds.write('# shock y direction \n') 
        fileds.write(' '.join(map(str, shock_diry)) + '\n')
        fileds.write('# shock z direction \n') 
        fileds.write(' '.join(map(str, shock_dirz)) + '\n')
        fileds.close()

# %%
if save == True:
    with open(f'data/{snap}/shockbool_{snap}.pkl', 'wb') as filebool:
        pickle.dump(are_u_shock, filebool)

# %%
cross_sec = 0
if folder == 'sedov':
    delta_cs = 0.02
else:
    delta_cs = 2

# %%
# Plot 3 conditions (cross section)
if(len(X_shock1[np.abs(Z_shock1-cross_sec)<delta_cs])>1):
    if folder == 'sedov':
        plt.figure(figsize=(10,10))
        plt.xlim(-1.1,1.1)
        plt.ylim(-1.1,1.1)
    else:
        plt.figure(figsize=(10,6))
    plt.plot(X_shock1[np.abs(Z_shock1-cross_sec)<delta_cs], Y_shock1[np.abs(Z_shock1-cross_sec)<delta_cs], 'ks', c = 'k', markerfacecolor='none', ms=8, markeredgecolor='coral', label = '1')
    plt.plot(X_shock2[np.abs(Z_shock2-cross_sec)<delta_cs], Y_shock2[np.abs(Z_shock2-cross_sec)<delta_cs], 'ks', c = 'k', markerfacecolor='orange', ms=6, markeredgecolor='orange', label = '1,2')
    plt.plot(X_shock[np.abs(Z_shock-cross_sec)<delta_cs], Y_shock[np.abs(Z_shock-cross_sec)<delta_cs], 'ks', c = 'k', markerfacecolor='k', ms=4, markeredgecolor='k', label = '1,2,3')
    plt.xlabel('X', fontsize = 18)
    plt.ylabel('Y', fontsize = 18)
    plt.legend(loc = 'upper left', fontsize = 18)
    plt.grid()
    plt.title(f'Conditions shock zone, z={cross_sec}', fontsize = 18)
    if save:    
        plt.savefig(f'Figs/{snap}/3XYshockzone_conditions_{snap}.png')
    plt.show()
# Out:
# /var/folders/s6/3n46ppqn3jx7765w8c686c740000gn/T/ipykernel_93089/776165656.py:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ks" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(X_shock1[np.abs(Z_shock1-cross_sec)<delta_cs], Y_shock1[np.abs(Z_shock1-cross_sec)<delta_cs], 'ks', c = 'k', markerfacecolor='none', ms=8, markeredgecolor='coral', label = '1')
# /var/folders/s6/3n46ppqn3jx7765w8c686c740000gn/T/ipykernel_93089/776165656.py:10: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ks" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(X_shock2[np.abs(Z_shock2-cross_sec)<delta_cs], Y_shock2[np.abs(Z_shock2-cross_sec)<delta_cs], 'ks', c = 'k', markerfacecolor='orange', ms=6, markeredgecolor='orange', label = '1,2')
# /var/folders/s6/3n46ppqn3jx7765w8c686c740000gn/T/ipykernel_93089/776165656.py:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ks" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(X_shock[np.abs(Z_shock-cross_sec)<delta_cs], Y_shock[np.abs(Z_shock-cross_sec)<delta_cs], 'ks', c = 'k', markerfacecolor='k', ms=4, markeredgecolor='k', label = '1,2,3')

# %%
if(len(Y_shock1[np.abs(X_shock1-cross_sec)<delta_cs])>1):
    if folder == 'sedov':
        plt.figure(figsize=(10,10))
        plt.xlim(-1.1,1.1)
        plt.ylim(-1.1,1.1)
    else:
        plt.figure(figsize=(10,6))
    plt.plot(Y_shock1[np.abs(X_shock1-cross_sec)<delta_cs], Z_shock1[np.abs(X_shock1-cross_sec)<delta_cs], 'ks', c = 'k', markerfacecolor='none', ms=8, markeredgecolor='b', label = '1')
    plt.plot(Y_shock2[np.abs(X_shock2-cross_sec)<delta_cs], Z_shock2[np.abs(X_shock2-cross_sec)<delta_cs], 'ks', c = 'k', markerfacecolor='turquoise', ms=6, markeredgecolor='turquoise', label = '12')
    plt.plot(Y_shock[np.abs(X_shock-cross_sec)<delta_cs], Z_shock[np.abs(X_shock-cross_sec)<delta_cs], 'ks', c = 'k', markerfacecolor='k', ms=4, markeredgecolor='k', label = '123')
    plt.xlabel('Y', fontsize = 18)
    plt.ylabel('Z', fontsize = 18)
    plt.legend(loc = 'upper left', fontsize = 18)
    plt.grid()
    plt.title(f'Conditions shock zone, x={cross_sec}', fontsize = 18)
    if save:    
        plt.savefig(f'Figs/{snap}/3YZshockzone_conditions_{snap}.png')
    plt.show()

# %%
if(len(X_shock1[np.abs(Y_shock1-cross_sec)<delta_cs])>1):
    if folder == 'sedov':
        plt.figure(figsize=(10,10))
        plt.xlim(-1.1,1.1)
        plt.ylim(-1.1,1.1)
    else:
        plt.figure(figsize=(10,6))
    plt.plot(X_shock1[np.abs(Y_shock1-cross_sec)<delta_cs], Z_shock1[np.abs(Y_shock1-cross_sec)<delta_cs], 'ks', c = 'k', markerfacecolor='none', ms=8, markeredgecolor='purple', label = '1')
    plt.plot(X_shock2[np.abs(Y_shock2-cross_sec)<delta_cs], Z_shock2[np.abs(Y_shock2-cross_sec)<delta_cs], 'ks', c = 'k', markerfacecolor='magenta', ms=6, markeredgecolor='magenta', label = '12')
    plt.plot(X_shock[np.abs(Y_shock-cross_sec)<delta_cs], Z_shock[np.abs(Y_shock-cross_sec)<delta_cs], 'ks', c = 'k', markerfacecolor='k', ms=4, markeredgecolor='k', label = '123')
    plt.xlabel('X', fontsize = 18)
    plt.ylabel('Z', fontsize = 18)
    plt.legend(loc = 'lower left', fontsize = 18)
    plt.grid()
    plt.title(f'Conditions shock zone, y={cross_sec}', fontsize = 18)
    if save:    
        plt.savefig(f'Figs/{snap}/3XZshockzone_conditions_{snap}.png')
    plt.show()

# %%
if folder == 'sedov':
    plt.figure(figsize=(8,8))
    plt.plot(X_shock[np.abs(Z_shock-cross_sec)<delta_cs], Y_shock[np.abs(Z_shock-cross_sec)<delta_cs], 'ks', c = 'k', markerfacecolor='k', ms=5, markeredgecolor='k')
    plt.xlabel('X', fontsize = 18)
    plt.ylabel('Y', fontsize = 18)
    plt.xlim(-1.1,1.1)
    plt.ylim(-1.1,1.1)
    plt.title(f'Shock zone, z = {cross_sec}', fontsize = 18)

if folder == 'TDE':
    plt.figure(figsize=(14,7))
    img = plt.scatter(X[::200]/20_000, Y[::200]/20_000, c = np.log10(Temp[::200]), alpha = 0.5, vmin = 2, vmax = 8)
    cbar = plt.colorbar(img)
    cbar.set_label(r'$\log_{10}$Temperature', fontsize = 18)
    plt.plot(X_shock/20_000, Y_shock/20_000, 'ks',  markerfacecolor='none', ms=5, markeredgecolor='k', label = 'shock zone')
    plt.xlabel(r'X [x/$R_a$]', fontsize = 18)
    plt.ylabel(r'Y [x/$R_a$]', fontsize = 18)
    plt.ylim(-0.3, 0.2)
    plt.xlim(-1,0.05)
    plt.title(f'Shock zone (projection) snap {snap}', fontsize = 18)

plt.grid()
if save:
    plt.savefig(f'Figs/{snap}/shockzone_{snap}.png')
plt.show()

# %%
if(len(x_who)>1):
    x_who = np.array(x_who)
    y_who = np.array(y_who)
    z_who = np.array(z_who)

    plt.figure(figsize=(10,10))
    plt.scatter(x_who, y_who,  c = 'b', label = 'wrong')
    plt.plot(X_shock, Y_shock, 'ks', c = 'k', markerfacecolor='none', ms=5, markeredgecolor='k', label = 'shock zone')
    plt.xlim(-1.1,1.1)
    plt.ylim(-1.1,1.1)
    plt.xlabel('X', fontsize = 18)
    plt.ylabel('Y', fontsize = 18)
    plt.legend()
    plt.grid()
    plt.title(r'Is ds = nan?', fontsize = 18)
    plt.legend()
    if save:
        plt.savefig(f'Figs/{snap}/4who_{snap}.png')
    plt.show()
